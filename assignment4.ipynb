# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/WineQT.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
print(df.head())


print(df.describe())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
print(df.isnull().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.tail(3)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
pd.unique(df['chlorides'])
# Out:
# array([0.076, 0.098, 0.092, 0.075, 0.069, 0.065, 0.073, 0.097, 0.089,
#        0.114, 0.341, 0.082, 0.106, 0.084, 0.085, 0.08 , 0.083, 0.103,
#        0.086, 0.066, 0.074, 0.088, 0.332, 0.054, 0.068, 0.081, 0.11 ,
#        0.07 , 0.079, 0.115, 0.093, 0.104, 0.062, 0.107, 0.045, 0.102,
#        0.077, 0.467, 0.09 , 0.178, 0.119, 0.118, 0.049, 0.05 , 0.117,
#        0.087, 0.61 , 0.095, 0.071, 0.072, 0.1  , 0.058, 0.067, 0.27 ,
#        0.111, 0.061, 0.056, 0.039, 0.06 , 0.101, 0.057, 0.337, 0.078,
#        0.263, 0.063, 0.611, 0.064, 0.096, 0.358, 0.091, 0.105, 0.094,
#        0.112, 0.213, 0.214, 0.121, 0.128, 0.052, 0.12 , 0.116, 0.109,
#        0.099, 0.122, 0.059, 0.047, 0.127, 0.152, 0.053, 0.055, 0.051,
#        0.125, 0.2  , 0.226, 0.25 , 0.108, 0.124, 0.222, 0.157, 0.422,
#        0.034, 0.387, 0.415, 0.241, 0.19 , 0.132, 0.126, 0.038, 0.044,
#        0.041, 0.165, 0.048, 0.147, 0.012, 0.194, 0.161, 0.123, 0.046,
# ...

# %%
df = df.drop(['fixed acidity'], axis=1)
df.head(5)
# Out:
#    volatile acidity  citric acid  residual sugar  free sulfur dioxide  \
# 0              0.70         0.00             1.9                 11.0
# 1              0.88         0.00             2.6                 25.0
# 2              0.76         0.04             2.3                 15.0
# 3              0.28         0.56             1.9                 17.0
# 4              0.70         0.00             1.9                 11.0
#
#    total sulfur dioxide  density    pH  sulphates  alcohol  quality  Id
# 0                  34.0   0.9978  3.51       0.56      9.4        5   0
# 1                  67.0   0.9968  3.20       0.68      9.8        5   1
# 2                  54.0   0.9970  3.26       0.65      9.8        5   2
# 3                  60.0   0.9980  3.16       0.58      9.8        6   3
# 4                  34.0   0.9978  3.51       0.56      9.4        5   4

# %%
df = df.rename(columns={"fixed acidity": "sugar", "residual sugar": "sugar", "free sulfur dioxide": "sulphur dioxide" })
df.head(5)
# Out:
#    volatile acidity  citric acid  sugar  sulphur dioxide  \
# 0              0.70         0.00    1.9             11.0
# 1              0.88         0.00    2.6             25.0
# 2              0.76         0.04    2.3             15.0
# 3              0.28         0.56    1.9             17.0
# 4              0.70         0.00    1.9             11.0
#
#    total sulfur dioxide  density    pH  sulphates  alcohol  quality  Id
# 0                  34.0   0.9978  3.51       0.56      9.4        5   0
# 1                  67.0   0.9968  3.20       0.68      9.8        5   1
# 2                  54.0   0.9970  3.26       0.65      9.8        5   2
# 3                  60.0   0.9980  3.16       0.58      9.8        6   3
# 4                  34.0   0.9978  3.51       0.56      9.4        5   4

# %%
df.shape
# Out:
# (1143, 11)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 11)

# %%
df.count()
# Out:
# volatile acidity        1143
# citric acid             1143
# sugar                   1143
# sulphur dioxide         1143
# total sulfur dioxide    1143
# density                 1143
# pH                      1143
# sulphates               1143
# alcohol                 1143
# quality                 1143
# Id                      1143
# dtype: int64

# %%
df = df.dropna()
df.count()
# Out:
# volatile acidity        1143
# citric acid             1143
# sugar                   1143
# sulphur dioxide         1143
# total sulfur dioxide    1143
# density                 1143
# pH                      1143
# sulphates               1143
# alcohol                 1143
# quality                 1143
# Id                      1143
# dtype: int64

# %%
sns.boxplot(x=df['volatile acidity'])
# Out:
# <Axes: xlabel='volatile acidity'>

# %%
sns.boxplot(x=df['sugar'])
# Out:
# <Axes: xlabel='sugar'>

# %%
df.sugar.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("quality of wine")
plt.ylabel('volatile acidity')
plt.xlabel('sugar')
# Out:
# Text(0.5, 0, 'sugar')

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['sugar'])
# Out:
# <Axes: xlabel='sugar', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['sugar'], y=df['volatile acidity'])
# Out:
# <Axes: xlabel='sugar', ylabel='volatile acidity'>

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df['sugar'],y=df['volatile acidity'])
# Out:
# <Axes: xlabel='sugar', ylabel='volatile acidity'>

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,annot=True)
# Out:
# <Axes: >
